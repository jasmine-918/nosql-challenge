# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
from pymongo import MongoClient

# Create an instance of MongoClient with the specified port
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017")


database_names = client.list_database_names()

# Check if the "uk_food" database is in the list
if "uk_food" in database_names:
    print("The 'uk_food' database was successfully created.")
else:
    print("The 'uk_food' database does not exist.")
# Out:
# The 'uk_food' database was successfully created.

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
from pymongo import MongoClient

# Create an instance of MongoClient
client = MongoClient("mongodb://localhost:27017")

# Access the "uk_food" database
db = client['uk_food']

# List the collections in the database
collection_names = db.list_collection_names()

# Print the collection names
for collection in collection_names:
    print(collection)
# Out:
# establishments

# %%
# review the collections in our new database
from pymongo import MongoClient

# Create an instance of MongoClient
client = MongoClient("mongodb://localhost:27017")

# Access the "uk_food" database
db = client['uk_food']

# List the collections in the database
collection_names = db.list_collection_names()

# Print the collection names
for collection_name in collection_names:
    print(collection_name)
# Out:
# establishments

# %%
# review a document in the establishments collection
from pymongo import MongoClient

# Create an instance of MongoClient
client = MongoClient("mongodb://localhost:27017")

# Access the "uk_food" database
db = client['uk_food']

# Access the "establishments" collection
collection = db['establishments']

# Find and print a single document from the collection
document = collection.find_one()
print(document)
# Out:
# {'_id': ObjectId('652889595c2ad99ffe6b70f2'), 'FHRSID': 254250, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000066174', 'BusinessName': 'The Pines Calyx', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'The Pines Garden', 'AddressLine2': 'Beach Road', 'AddressLine3': 'St Margarets Bay', 'AddressLine4': 'Kent', 'PostCode': 'CT15 6DZ', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2021-08-17T00:00:00', 'LocalAuthorityCode': '182', 'LocalAuthorityName': 'Dover', 'LocalAuthorityWebSite': 'http://www.dover.gov.uk/', 'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '1.383298', 'latitude': '51.148133'}, 'RightToReply': '', 'Distance': 4587.362402580997, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, '
# ...

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "name": "New Restaurant Name",
    "address": "123 Main Street",
    "city": "City",
    "zipcode": "12345",
    "cuisine": "Cuisine Type",
    "rating": 4.5,
    "hygiene_score": 5,
    "is_vegetarian": False,
    "menu_items": ["Item1", "Item2", "Item3"],
    "opening_hours": {
        "monday": "9:00 AM - 10:00 PM",
        "tuesday": "9:00 AM - 10:00 PM",
        "wednesday": "9:00 AM - 10:00 PM",
        "thursday": "9:00 AM - 10:00 PM",
        "friday": "9:00 AM - 10:00 PM",
        "saturday": "9:00 AM - 11:00 PM",
        "sunday": "10:00 AM - 9:00 PM"
    }
}

# %%
# Insert the new restaurant into the collection
from pymongo import MongoClient

# Create an instance of MongoClient
client = MongoClient("mongodb://localhost:27017")

# Access the "uk_food" database
db = client['uk_food']

# Access the "establishments" collection
collection = db['establishments']

# Create a dictionary for the new restaurant data
new_restaurant = {
    "name": "New Restaurant Name",
    "address": "123 Main Street",
    "city": "City",
    "zipcode": "12345",
    "cuisine": "Cuisine Type",
    "rating": 4.5,
    "hygiene_score": 5,
    "is_vegetarian": False,
    "menu_items": ["Item1", "Item2", "Item3"],
    "opening_hours": {
        "monday": "9:00 AM - 10:00 PM",
        "tuesday": "9:00 AM - 10:00 PM",
        "wednesday": "9:00 AM - 10:00 PM",
        "thursday": "9:00 AM - 10:00 PM",
        "friday": "9:00 AM - 10:00 PM",
        "saturday": "9:00 AM - 11:00 PM",
        "sunday": "10:00 AM - 9:00 PM"
    }
}

# Insert the new restaurant data into the collection
result = collection.insert_one(new_restaurant)

# Print the inserted document's ID
print("Inserted document ID:", result.inserted_id)
# Out:
# Inserted document ID: 652899a0ee0512d51cbd76a7

# %%
# Check that the new restaurant was inserted
from pymongo import MongoClient

# Create an instance of MongoClient
client = MongoClient("mongodb://localhost:27017")

# Access the "uk_food" database
db = client['uk_food']

# Access the "establishments" collection
collection = db['establishments']

# Define a query to find the newly inserted restaurant by its name
query = {"name": "New Restaurant Name"}

# Use find_one() to retrieve the restaurant with the specified name
newly_inserted_restaurant = collection.find_one(query)

# Check if the restaurant was found
if newly_inserted_restaurant:
    print("New restaurant found:")
    print(newly_inserted_restaurant)
else:
    print("New restaurant not found.")
# Out:
# New restaurant found:
# {'_id': ObjectId('652899a0ee0512d51cbd76a7'), 'name': 'New Restaurant Name', 'address': '123 Main Street', 'city': 'City', 'zipcode': '12345', 'cuisine': 'Cuisine Type', 'rating': 4.5, 'hygiene_score': 5, 'is_vegetarian': False, 'menu_items': ['Item1', 'Item2', 'Item3'], 'opening_hours': {'monday': '9:00 AM - 10:00 PM', 'tuesday': '9:00 AM - 10:00 PM', 'wednesday': '9:00 AM - 10:00 PM', 'thursday': '9:00 AM - 10:00 PM', 'friday': '9:00 AM - 10:00 PM', 'saturday': '9:00 AM - 11:00 PM', 'sunday': '10:00 AM - 9:00 PM'}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
from pymongo import MongoClient

# Create an instance of MongoClient
client = MongoClient("mongodb://localhost:27017")

# Access the "uk_food" database
db = client['uk_food']

# Access the "establishments" collection
collection = db['establishments']

# Define the query to find the BusinessTypeID for "Restaurant/Cafe/Canteen"
query = {"BusinessType": "Restaurant/Cafe/Canteen"}

# Specify the projection to return only the BusinessTypeID and BusinessType fields
projection = {"_id": 0, "BusinessTypeID": 1, "BusinessType": 1}

# Use find() with the query and projection
result = collection.find(query, projection)

# Print the results
for document in result:
    print(document)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# ...

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
from pymongo import MongoClient

# Create an instance of MongoClient
client = MongoClient("mongodb://localhost:27017")

# Access the "uk_food" database
db = client['uk_food']

# Access the "establishments" collection
collection = db['establishments']

# Define a query to find the restaurant by its name
query = {"name": "New Restaurant Name"}

# Define the new value for the BusinessTypeID field
new_business_type_id = "Your New BusinessTypeID Value"

# Create an update document with the $set operator to update the BusinessTypeID
update_document = {
    "$set": {"BusinessTypeID": new_business_type_id}
}

# Use update_one() to update the document
result = collection.update_one(query, update_document)

# Check if the update was successful
if result.modified_count > 0:
    print("Restaurant updated successfully.")
else:
    print("Restaurant not found or not updated.")
# Out:
# Restaurant updated successfully.

# %%
# Confirm that the new restaurant was updated
from pymongo import MongoClient

# Create an instance of MongoClient
client = MongoClient("mongodb://localhost:27017")

# Access the "uk_food" database
db = client['uk_food']

# Access the "establishments" collection
collection = db['establishments']

# Define a query to find the restaurant by its name
query = {"name": "New Restaurant Name"}

# Use find_one() to retrieve the restaurant
updated_restaurant = collection.find_one(query)

# Check if the updated restaurant was found
if updated_restaurant:
    print("Updated restaurant found:")
    print(updated_restaurant)
else:
    print("Updated restaurant not found.")
# Out:
# Updated restaurant found:
# {'_id': ObjectId('652899a0ee0512d51cbd76a7'), 'name': 'New Restaurant Name', 'address': '123 Main Street', 'city': 'City', 'zipcode': '12345', 'cuisine': 'Cuisine Type', 'rating': 4.5, 'hygiene_score': 5, 'is_vegetarian': False, 'menu_items': ['Item1', 'Item2', 'Item3'], 'opening_hours': {'monday': '9:00 AM - 10:00 PM', 'tuesday': '9:00 AM - 10:00 PM', 'wednesday': '9:00 AM - 10:00 PM', 'thursday': '9:00 AM - 10:00 PM', 'friday': '9:00 AM - 10:00 PM', 'saturday': '9:00 AM - 11:00 PM', 'sunday': '10:00 AM - 9:00 PM'}, 'BusinessTypeID': 'Your New BusinessTypeID Value'}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
from pymongo import MongoClient

# Create an instance of MongoClient
client = MongoClient("mongodb://localhost:27017")

# Access the "uk_food" database
db = client['uk_food']

# Access the "establishments" collection
collection = db['establishments']

# Define the query to find documents with LocalAuthorityName as "Dover"
query = {"LocalAuthorityName": "Dover"}

# Use count_documents() to count the matching documents
count = collection.count_documents(query)

# Print the count of documents
print("Number of documents with LocalAuthorityName 'Dover':", count)
# Out:
# Number of documents with LocalAuthorityName 'Dover': 1988

# %%
# Delete all documents where LocalAuthorityName is "Dover"

from pymongo import MongoClient


client = MongoClient("mongodb://localhost:27017")

# Access the "uk_food" database
db = client['uk_food']

# Access the "establishments" collection
collection = db['establishments']

# Define the query to find documents with LocalAuthorityName as "Dover"
query = {"LocalAuthorityName": "Dover"}

# Use delete_many() to delete the matching documents
result = collection.delete_many(query)

# Print the number of deleted documents
print("Number of documents deleted:", result.deleted_count)
# Out:
# Number of documents deleted: 1988

# %%
from pymongo import MongoClient

# Create an instance of MongoClient
client = MongoClient("mongodb://localhost:27017")

# Access the "uk_food" database
db = client['uk_food']

# Access the "establishments" collection
collection = db['establishments']

# Define a query to find documents with LocalAuthorityName as "Dover"
query = {"LocalAuthorityName": "Dover"}

# Use count_documents() to count the matching documents
count = collection.count_documents(query)

# Check if any documents were found
if count > 0:
    print("There are remaining documents with LocalAuthorityName 'Dover'.")
else:
    print("No documents with LocalAuthorityName 'Dover' were found.")
# Out:
# No documents with LocalAuthorityName 'Dover' were found.

# %%
# Check that other documents remain with 'find_one'
from pymongo import MongoClient

# Create an instance of MongoClient
client = MongoClient("mongodb://localhost:27017")

# Access the "uk_food" database
db = client['uk_food']

# Access the "establishments" collection
collection = db['establishments']

# Use find_one() to retrieve a single document from the collection
document = collection.find_one()

# Check if a document was found
if document:
    print("Other documents remain in the collection.")
else:
    print("No other documents were found in the collection.")
# Out:
# Other documents remain in the collection.

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
from pymongo import MongoClient

# Create an instance of MongoClient
client = MongoClient("mongodb://localhost:27017")

# Access the "uk_food" database
db = client['uk_food']

# Access the "establishments" collection
collection = db['establishments']

# Define a query to select documents where the "longitude" and "latitude" fields are strings
query = {
    "longitude": {"$type": "string"},
    "latitude": {"$type": "string"}
}

# Use find() to retrieve the documents matching the query
documents_to_update = collection.find(query)

# Iterate through the documents and update the data type of "longitude" and "latitude"
for document in documents_to_update:
    updated_document = {
        "$set": {
            "longitude": float(document["longitude"]),
            "latitude": float(document["latitude"])
        }
    }
    # Update the document with the new data types
    collection.update_one({"_id": document["_id"]}, updated_document)

print("Data type updated for 'longitude' and 'latitude' fields.")
# Out:
# Data type updated for 'longitude' and 'latitude' fields.

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
from pymongo import MongoClient

# Create an instance of MongoClient
client = MongoClient("mongodb://localhost:27017")

# Access the "uk_food" database
db = client['uk_food']

# Access the "establishments" collection
collection = db['establishments']

# Define a query to select documents where the "RatingValue" field is a string
query = {
    "RatingValue": {"$type": "string"}
}

# Use find() to retrieve the documents matching the query
documents_to_update = collection.find(query)

# Iterate through the documents and update the data type of "RatingValue"
for document in documents_to_update:
    updated_document = {
        "$set": {
            "RatingValue": int(document["RatingValue"])
        }
    }
    # Update the document with the new data type
    collection.update_one({"_id": document["_id"]}, updated_document)

print("Data type updated for 'RatingValue' field.")
# Out:
# Data type updated for 'RatingValue' field.

# %%
# Check that the coordinates and rating value are now numbers
from pymongo import MongoClient

# Create an instance of MongoClient
client = MongoClient("mongodb://localhost:27017")

# Access the "uk_food" database
db = client['uk_food']

# Access the "establishments" collection
collection = db['establishments']

# Check the data types for "longitude" and "latitude" fields
for document in collection.find({"longitude": {"$type": "double"}, "latitude": {"$type": "double"}}):
    print("Coordinates are of numeric data type.")
    break
else:
    print("No documents with numeric coordinates found.")

# Check the data type for "RatingValue" field
for document in collection.find({"RatingValue": {"$type": "int"}}):
    print("RatingValue is of numeric data type.")
    break
else:
    print("No documents with numeric RatingValue found.")
# Out:
# No documents with numeric coordinates found.
# RatingValue is of numeric data type.
